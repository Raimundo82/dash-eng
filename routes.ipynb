# %%
import pandas as pd
routes = pd.read_csv('./routes.csv')
# Out:
#    ship_id vessel_type  speed_max  speed_min  speed_mean  speed_std  speed_25  \
# 0    25520       Cargo       14.9       12.4   13.884247   0.636985      13.7
# 1    23714       Cargo       13.3        6.0   12.400000   0.757928      12.3
# 2    29442         NaN       22.1        0.0    2.161382   5.877217       0.0
# 3    30083       Cargo       10.6        7.9    8.999138   0.687338       8.4
# 4    30083       Cargo       12.8        0.0    8.312164   3.078415       8.7
#
#    speed_50  speed_75  course_max  ...  bearing_change_25  bearing_change_50  \
# 0      14.0    14.400       274.0  ...                0.0                0.0
# 1      12.4    12.700        96.0  ...                0.0                0.0
# 2       0.0     0.100       360.0  ...               43.0              105.0
# 3       9.1     9.525       359.0  ...                0.0                1.0
# 4       9.1    10.000       358.0  ...                0.0                1.0
#
# ...
